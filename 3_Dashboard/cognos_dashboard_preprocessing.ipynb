# %%
import pandas as pd

# %%
df = pd.read_csv('survey_data_updated.csv')
df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           2                     I am a developer by profession
# 1           3                     I am a developer by profession
# 2          10                     I am a developer by profession
# 3          11  I used to be a developer by profession, but no...
# 4          12                     I am a developer by profession
#
#                Age                                         Employment  \
# 0  35-44 years old                                Employed, full-time
# 1  45-54 years old                                Employed, full-time
# 2  35-44 years old  Independent contractor, freelancer, or self-em...
# 3  35-44 years old                                Employed, full-time
# 4  45-54 years old                                Employed, full-time
#
#   RemoteWork   Check                                   CodingActivities  \
# 0     Remote  Apples  Hobby;Contribute to open-source projects;Other...
# ...

# %%
#  Strip whitespace from all string fields
df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_4668\4005556958.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)

# %%
missing_df= df.isnull().reset_index()

# %%
#  Fill missing values for key demographic fields
df['Country'] = df['Country'].fillna('Unknown')
df['EdLevel'] = df['EdLevel'].fillna('Unknown')

# %%
# Split multi-value Column- 
# Step 5: Explode all multi-value columns
multi_value_cols = [
    'LanguageHaveWorkedWith', 'DatabaseHaveWorkedWith', 'PlatformHaveWorkedWith', 'WebframeHaveWorkedWith',
    'LanguageWantToWorkWith', 'DatabaseWantToWorkWith', 'PlatformWantToWorkWith', 'WebframeWantToWorkWith'
]

for col in multi_value_cols:
    df[col] = df[col].fillna('')
    df[col] = df[col].apply(lambda x: [i.strip() for i in str(x).split(';')] if x else [])

# %%
exploded_frames = []

for col in multi_value_cols:
    temp = df[['ResponseId', 'Age', 'Country', 'EdLevel']].copy()
    temp[col] = df[col]
    temp = temp.explode(col)
    temp = temp[temp[col] != '']
    temp.rename(columns={col: 'Value'}, inplace=True)
    temp['Source'] = col
    exploded_frames.append(temp)

# Combine all exploded frames
df_exploded = pd.concat(exploded_frames, ignore_index=True)

# %%
df_exploded.to_csv('survey_cleaned.csv.gz', index=False, compression='gzip')

# %%
print('Done')
# Out:
# Done
